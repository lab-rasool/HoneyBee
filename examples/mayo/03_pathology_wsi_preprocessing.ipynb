# %% [markdown]
# # HoneyBee Workshop Part 3: Pathology WSI Preprocessing
#
# ## Overview
# In this workshop, you'll learn how to:
# 1. Load and process Whole Slide Images (WSI)
# 2. Extract tissue regions and patches
# 3. Generate pathology embeddings using UNI and Virchow models
# 4. Handle multi-resolution gigapixel images
#
# **Duration**: 30 minutes
#
# **Prerequisites**:
# - HoneyBee environment setup
# - OpenSlide installed
# - UNI/Virchow model weights at `/mnt/d/Models/`

# %% [markdown]
# ## 1. Setup and Imports

# %%
import os
import sys
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# Add HoneyBee to path
sys.path.append('/mnt/f/Projects/HoneyBee')

# Import HoneyBee components
from honeybee.loaders import Slide
from honeybee.processors import PathologyProcessor
from honeybee.models import UNI, TissueDetector

# Import additional utilities
import torch
import cv2

print("HoneyBee pathology processing modules loaded successfully!")
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
# Out:
# HoneyBee pathology processing modules loaded successfully!
# PyTorch version: 2.7.0+cu126
# CUDA available: True

# %% [markdown]
# ## 2. Load Sample WSI Data, Tissue Detection, and Segmentation
#
# We'll use the sample whole slide image from the examples folder.

# %%
# Path to sample WSI
wsi_path = "/mnt/f/Projects/HoneyBee/examples/samples/sample.svs"

tissue_detector = TissueDetector("/mnt/d/Models/TissueDetector/HnE.pt")

# Initialize slide loader
slide = Slide(
    slide_image_path=wsi_path,
    tile_size=512,
    tileOverlap=0,
    max_patches=500,
    visualize=True,
    tissue_detector=tissue_detector,
    path_to_store_visualization="./visualizations",
    verbose=True,
)
# Out:
# Resolutions: {'level_count': 3, 'level_dimensions': ((27965, 25146), (6991, 6286), (1747, 1571)), 'level_downsamples': (1.0, 4.00023078918457, 16.00690269470215), 'level_tile_sizes': ((240, 240), (240, 240), (240, 240))}
# Level 0: 54x49 (2646) 	 Resolution: 27965x25146
# Level 1: 13x12 (156) 	 Resolution: 6991x6286
# Selected level 1 with dimensions: 6286x6991

# %%
# TODO: Patch extraction
# TODO: Staining
# TODO: Embedding generation
