# %% [markdown]
# ## Import libararies

# %%
import numpy as np
import SimpleITK as sitk
from matplotlib import pyplot as plt

# %% [markdown]
# ## Reading Nifti Image

# %% [markdown]
# We are going to use *SimpleITK* python Libarary for most of our preprocessing task in this Notebook.Hopefully you will be find it very easy to use

# %%
# Reading- Image
#-|path of the data
ct_path='/mnt/f/Projects/HoneyBee/data/img0001.nii.gz'
ct_label_path='/mnt/f/Projects/HoneyBee/data/label0001.nii.gz'
slice_no=120

# CT
img_sitk  = sitk.ReadImage(ct_path, sitk.sitkFloat32) # Reading CT
image     = sitk.GetArrayFromImage(img_sitk) #Converting sitk_metadata to image Array
# Mask
mask_sitk = sitk.ReadImage(ct_label_path,sitk.sitkInt32) # Reading CT
mask      = sitk.GetArrayFromImage(mask_sitk)#Converting sitk_metadata to image Array

print('CT Shape={}'.format(image.shape))
print('CT Mask Shape={}'.format(mask.shape))

#----Lets plot 
fontsize = 16
f, axarr = plt.subplots(1,3,figsize=(15,15))
axarr[0].imshow(np.squeeze(image[slice_no, :, :]), cmap='gray',origin='lower')
axarr[0].set_ylabel('Axial View',fontsize=fontsize)
axarr[0].set_xticks([])
axarr[0].set_yticks([])
axarr[0].set_title('CT',fontsize=fontsize)

axarr[1].imshow(np.squeeze(mask[slice_no, :, :]), cmap='jet',origin='lower')
axarr[1].axis('off')
axarr[1].set_title('Mask',fontsize=fontsize)

axarr[2].imshow(np.squeeze(image[slice_no, :, :]), cmap='gray',alpha=1,origin='lower')
axarr[2].imshow(np.squeeze(mask[slice_no, :, :]),cmap='jet',alpha=0.5,origin='lower')
axarr[2].axis('off')
axarr[2].set_title('Overlay',fontsize=fontsize)
plt.tight_layout()
plt.subplots_adjust(wspace=0, hspace=0)
plt.show()
# Out:
# CT Shape=(147, 512, 512)
# CT Mask Shape=(147, 512, 512)

# %%
# plot the various masked images into their respective subplots
# use the mask to \text{imROI} = \text{im} \cdot \text{mask} to get the masked image ROI
# use ct_label_path

import numpy as np
import SimpleITK as sitk
import matplotlib.pyplot as plt

slice_no = 110

# Get unique values from mask (excluding background 0)
unique_labels = np.unique(mask)[1:]
n_objects = len(unique_labels)

# Create subplot grid
rows = int(np.ceil((n_objects + 2) / 3))  # +2 for CT and full mask
fig, axarr = plt.subplots(rows, 3, figsize=(15, 5*rows))
axarr = axarr.ravel()

# Plot original CT
axarr[0].imshow(np.squeeze(image[slice_no, :, :]), cmap='gray', origin='lower')
axarr[0].set_title('Original CT', fontsize=fontsize)
axarr[0].axis('off')

# Plot full mask
axarr[1].imshow(np.squeeze(mask[slice_no, :, :]), cmap='jet', origin='lower')
axarr[1].set_title('Full Mask', fontsize=fontsize)
axarr[1].axis('off')

# Plot individual object masks
for idx, label in enumerate(unique_labels, start=2):
    # Create binary mask for this object
    object_mask = (mask[slice_no, :, :] == label)
    # Apply mask to CT image
    masked_ct = image[slice_no, :, :] * object_mask
    
    axarr[idx].imshow(masked_ct, cmap='gray', origin='lower')
    axarr[idx].set_title(f'Object {label}', fontsize=fontsize)
    axarr[idx].axis('off')

# Remove empty subplots
for idx in range(len(unique_labels)+2, len(axarr)):
    fig.delaxes(axarr[idx])

plt.tight_layout()
plt.show()

# %% [markdown]
# # Intensity Normalization

# %% [markdown]
# Now we know how to load the nifti data. Next thing is to learn how to normalize the intensities

# %%
def normalise(image):
    # normalise and clip images -1000 to 800
    np_img = image
    np_img = np.clip(np_img, -1000., 800.).astype(np.float32)
    return np_img


def whitening(image):
    """Whitening. Normalises image to zero mean and unit variance."""

    image = image.astype(np.float32)

    mean = np.mean(image)
    std = np.std(image)

    if std > 0:
        ret = (image - mean) / std
    else:
        ret = image * 0.
    return ret


def normalise_zero_one(image):
    """Image normalisation. Normalises image to fit [0, 1] range."""

    image = image.astype(np.float32)

    minimum = np.min(image)
    maximum = np.max(image)

    if maximum > minimum:
        ret = (image - minimum) / (maximum - minimum)
    else:
        ret = image * 0.
    return ret


def normalise_one_one(image):
    """Image normalisation. Normalises image to fit [-1, 1] range."""

    ret = normalise_zero_one(image)
    ret *= 2.
    ret -= 1.
    return ret



Normalize_minun100_to_800hu=normalise(image)
Normalize_0mean_UnitVr=whitening(image)
Normalize_0to1=normalise_zero_one(image)
normalise_minus1_to1=normalise_one_one(image)

f, axarr = plt.subplots(1, 5, figsize=(20,5))
f.suptitle('Different intensity normalisation methods on a Abdomen CT')

img = axarr[0].imshow(np.squeeze(image[slice_no, :, :]), cmap='gray',origin='lower')
axarr[0].axis('off')
axarr[0].set_title('Original image')
f.colorbar(img, ax=axarr[0])

img = axarr[1].imshow(np.squeeze(Normalize_minun100_to_800hu[slice_no, :, :]), cmap='gray',origin='lower')
axarr[1].axis('off')
axarr[1].set_title('-1000 to 800')
f.colorbar(img, ax=axarr[1])

img = axarr[2].imshow(np.squeeze(Normalize_0mean_UnitVr[slice_no, :, :]), cmap='gray',origin='lower')
axarr[2].axis('off')
axarr[2].set_title('Zero mean/unit stdev')
f.colorbar(img, ax=axarr[2])

img = axarr[3].imshow(np.squeeze(Normalize_0to1[slice_no, :, :]), cmap='gray',origin='lower')
axarr[3].axis('off')
axarr[3].set_title('[0,1] rescaling')
f.colorbar(img, ax=axarr[3])

img = axarr[4].imshow(np.squeeze(normalise_minus1_to1[slice_no, :, :]), cmap='gray',origin='lower')
axarr[4].axis('off')
axarr[4].set_title('[-1,1] rescaling')
f.colorbar(img, ax=axarr[4])
    
f.subplots_adjust(wspace=0.05, hspace=0, top=0.8)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

ct_path='/mnt/f/Projects/HoneyBee/data/img0001.nii.gz'
ct_label_path='/mnt/f/Projects/HoneyBee/data/label0001.nii.gz'
slice_no=140

def window_image(image, window_min, window_max):
    """Apply windowing to an image based on HU range."""
    np_img = np.clip(image, window_min, window_max)
    np_img = (np_img - window_min) / (window_max - window_min)  # Normalize to [0,1]
    return np_img

# Define HU ranges
bone_window = (200, 1000)    # Bone window: 200 to 1000 HU
lung_window = (-1000, -300)  # Lung window: -1000 to -300 HU

# Apply windowing
image_bone = window_image(image, *bone_window)
image_lung = window_image(image, *lung_window)

# Plot original, bone, and lung windowed images
f, axarr = plt.subplots(1, 3, figsize=(15, 5))

# Original Image
img = axarr[0].imshow(np.squeeze(image[slice_no, :, :]), cmap='gray', origin='lower')
axarr[0].axis('off')
axarr[0].set_title('Original Image')
f.colorbar(img, ax=axarr[0])

# Bone Window
img = axarr[1].imshow(np.squeeze(image_bone[slice_no, :, :]), cmap='gray', origin='lower')
axarr[1].axis('off')
axarr[1].set_title('Bone Window (200 to 1000 HU)')
f.colorbar(img, ax=axarr[1])

# Lung Window
img = axarr[2].imshow(np.squeeze(image_lung[slice_no, :, :]), cmap='gray', origin='lower')
axarr[2].axis('off')
axarr[2].set_title('Lung Window (-1000 to -300 HU)')
f.colorbar(img, ax=axarr[2])

# Adjust layout and display
f.subplots_adjust(wspace=0.05, hspace=0, top=0.8)
plt.show()

# %% [markdown]
# # Resampling

# %%
def resample_img(itk_image, out_spacing=[2.0, 2.0, 2.0], is_label=False):
    # resample images to 2mm spacing with simple itk

    original_spacing = itk_image.GetSpacing()
    original_size = itk_image.GetSize()

    out_size = [
        int(np.round(original_size[0] * (original_spacing[0] / out_spacing[0]))),
        int(np.round(original_size[1] * (original_spacing[1] / out_spacing[1]))),
        int(np.round(original_size[2] * (original_spacing[2] / out_spacing[2])))]

    resample = sitk.ResampleImageFilter()
    resample.SetOutputSpacing(out_spacing)
    resample.SetSize(out_size)
    resample.SetOutputDirection(itk_image.GetDirection())
    resample.SetOutputOrigin(itk_image.GetOrigin())
    resample.SetTransform(sitk.Transform())
    resample.SetDefaultPixelValue(itk_image.GetPixelIDValue())

    if is_label:
        resample.SetInterpolator(sitk.sitkNearestNeighbor)
    else:
        resample.SetInterpolator(sitk.sitkBSpline)

    return resample.Execute(itk_image)


ct_resampled_to1m=resample_img(img_sitk, out_spacing=[1, 1, 1], is_label=False)
ct_resampled_to1m=sitk.GetArrayFromImage(ct_resampled_to1m)
mask_resampled_to1m=resample_img(mask_sitk, out_spacing=[1, 1, 1], is_label=True)
mask_resampled_to1m=sitk.GetArrayFromImage(mask_resampled_to1m)
print('CT Shape Original={}, Resampled to 1mm={}'.format(image.shape,ct_resampled_to1m.shape))
print('CT Mask Shape={}, Resampled to 1mm={}'.format(mask.shape,mask_resampled_to1m.shape))

#----Lets plot 
f, axarr = plt.subplots(1,3,figsize=(15,15))
axarr[0].imshow(np.squeeze(ct_resampled_to1m[250, :, :]), cmap='gray',origin='lower')
axarr[0].set_ylabel('Axial View',fontsize=14)
axarr[0].set_xticks([])
axarr[0].set_yticks([])
axarr[0].set_title('CT',fontsize=14)

axarr[1].imshow(np.squeeze(mask_resampled_to1m[250, :, :]), cmap='jet',origin='lower')
axarr[1].axis('off')
axarr[1].set_title('Mask',fontsize=14)

axarr[2].imshow(np.squeeze(ct_resampled_to1m[250, :, :]), cmap='gray',alpha=1,origin='lower')
axarr[2].imshow(np.squeeze(mask_resampled_to1m[250, :, :]),cmap='jet',alpha=0.5,origin='lower')
axarr[2].axis('off')
axarr[2].set_title('Overlay',fontsize=14)
plt.tight_layout()
plt.subplots_adjust(wspace=0, hspace=0)
# Out:
# CT Shape Original=(147, 512, 512), Resampled to 1mm=(441, 342, 342)
# CT Mask Shape=(147, 512, 512), Resampled to 1mm=(441, 342, 342)

# %% [markdown]
# # Crop or Padding

# %%
def resize_image_with_crop_or_pad(image, img_size=(64, 64, 64), **kwargs):
    """Image resizing by cropping or padding dimensions to fit specified size.
    
    Args:
        image (np.ndarray): Image to be resized.
        img_size (list or tuple): Target image size.
        kwargs (): Additional arguments for np.pad.
    
    Returns:
        np.ndarray: Resized image.
    """

    assert isinstance(image, (np.ndarray, np.generic))
    assert (image.ndim - 1 == len(img_size) or image.ndim == len(img_size)), \
        'Example size does not fit image size.'

    # Get the number of dimensions
    rank = len(img_size)

    # Create placeholders for cropping and padding
    from_indices = [[0, image.shape[dim]] for dim in range(rank)]
    to_padding = [[0, 0] for dim in range(rank)]

    slicer = [slice(None)] * rank  # Initialize slicer list

    for i in range(rank):
        if image.shape[i] < img_size[i]:  # Need to pad
            to_padding[i][0] = (img_size[i] - image.shape[i]) // 2
            to_padding[i][1] = img_size[i] - image.shape[i] - to_padding[i][0]
        else:  # Need to crop
            from_indices[i][0] = int(np.floor((image.shape[i] - img_size[i]) / 2.))
            from_indices[i][1] = from_indices[i][0] + img_size[i]

        # Create slicer object for cropping
        slicer[i] = slice(from_indices[i][0], from_indices[i][1])

    # Convert slicer to tuple before indexing
    return np.pad(image[tuple(slicer)], to_padding, **kwargs)



# Crop to [64, 64, 64]
img_cropped = resize_image_with_crop_or_pad(image, [96, 96, 96], mode='symmetric')

# Resizing image to [128, 256, 256] required padding
img_padded = resize_image_with_crop_or_pad(image, [256, 544, 544], mode='symmetric')

# Visualise using matplotlib.
f, axarr = plt.subplots(1, 3, figsize=(15,15))
axarr[0].imshow(np.squeeze(image[slice_no, :, :]), cmap='gray',origin='lower')
axarr[0].axis('off')
axarr[0].set_title('Original image {}'.format(image.shape))

axarr[1].imshow(np.squeeze(img_cropped[32, :, :]), cmap='gray',origin='lower')
axarr[1].axis('off')
axarr[1].set_title('Cropped to {}'.format(img_cropped.shape))

axarr[2].imshow(np.squeeze(img_padded[slice_no, :, :]), cmap='gray',origin='lower')
axarr[2].axis('off')
axarr[2].set_title('Padded to {}'.format(img_padded.shape))
plt.tight_layout()
plt.subplots_adjust(wspace=0, hspace=0)
